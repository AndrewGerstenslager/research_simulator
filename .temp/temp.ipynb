# %%
# %pip install pygame
# Out:
# ...
#    ---------------------------------------- 0.0/10.8 MB ? eta -:--:--
#    ---------------------------------------- 0.0/10.8 MB 660.6 kB/s eta 0:00:17
#    ---------------------------------------- 0.1/10.8 MB 1.3 MB/s eta 0:00:09
#     --------------------------------------- 0.2/10.8 MB 1.7 MB/s eta 0:00:07
#    - -------------------------------------- 0.3/10.8 MB 1.8 MB/s eta 0:00:06
#    - -------------------------------------- 0.4/10.8 MB 1.8 MB/s eta 0:00:06
#    - -------------------------------------- 0.5/10.8 MB 1.8 MB/s eta 0:00:06
#    -- ------------------------------------- 0.6/10.8 MB 1.9 MB/s eta 0:00:06
#    -- ------------------------------------- 0.6/10.8 MB 1.8 MB/s eta 0:00:06
#    -- ------------------------------------- 0.7/10.8 MB 1.9 MB/s eta 0:00:06
#    --- ------------------------------------ 0.8/10.8 MB 1.9 MB/s eta 0:00:06
#    --- ------------------------------------ 0.9/10.8 MB 1.8 MB/s eta 0:00:06
# ...

# %%
import pygame
# Out:
# pygame 2.6.0 (SDL 2.28.4, Python 3.12.2)
# Hello from the pygame community. https://www.pygame.org/contribute.html
